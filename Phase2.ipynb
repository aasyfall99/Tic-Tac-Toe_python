# %% [markdown]
# <a href="https://colab.research.google.com/github/aasyfall99/Tic-Tac-Toe_python/blob/main/Phase2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
buttons = []

    # Fonction pour vérifier si un joueur a gagné
def Win():
    # Lignes
    if panels[1] == panels[2] == panels[3]:
        return panels[1]
    elif panels[4] == panels[5] == panels[6]:
        return panels[4]
    elif panels[7] == panels[8] == panels[9]:
        return panels[7]
    # Colonnes
    elif panels[1] == panels[4] == panels[7]:
        return panels[1]
    elif panels[2] == panels[5] == panels[8]:
        return panels[2]
    elif panels[3] == panels[6] == panels[9]:
        return panels[3]
    # Diagonales
    elif panels[1] == panels[5] == panels[9]:
        return panels[1]
    elif panels[3] == panels[5] == panels[7]:
        return panels[3]
    else:
        return ""

# définition de la fonction de vérification (un seul coup par clic, via if/elif)
def verification(i):
    global count, mark

    if i == 1:
        if i in chiffres:
            chiffres.remove(i)
            if count % 2 == 0:
                mark = "X"
            else:
                mark = "O"
            panels[1] = mark
            buttons[0].config(text=mark)
            count += 1

    elif i == 2:
        if i in chiffres:
            chiffres.remove(i)
            if count % 2 == 0:
                mark = "X"
            else:
                mark = "O"
            panels[2] = mark
            buttons[1].config(text=mark)
            count += 1

    elif i == 3:
        if i in chiffres:
            chiffres.remove(i)
            if count % 2 == 0:
                mark = "X"
            else:
                mark = "O"
            panels[3] = mark
            buttons[2].config(text=mark)
            count += 1

    elif i == 4:
        if i in chiffres:
            chiffres.remove(i)
            if count % 2 == 0:
                mark = "X"
            else:
                mark = "O"
            panels[4] = mark
            buttons[3].config(text=mark)
            count += 1

    elif i == 5:
        if i in chiffres:
            chiffres.remove(i)
            if count % 2 == 0:
                mark = "X"
            else:
                mark = "O"
            panels[5] = mark
            buttons[4].config(text=mark)
            count += 1

    elif i == 6:
        if i in chiffres:
            chiffres.remove(i)
            if count % 2 == 0:
                mark = "X"
            else:
                mark = "O"
            panels[6] = mark
            buttons[5].config(text=mark)
            count += 1

    elif i == 7:
        if i in chiffres:
            chiffres.remove(i)
            if count % 2 == 0:
                mark = "X"
            else:
                mark = "O"
            panels[7] = mark
            buttons[6].config(text=mark)
            count += 1

    elif i == 8:
        if i in chiffres:
            chiffres.remove(i)
            if count % 2 == 0:
                mark = "X"
            else:
                mark = "O"
            panels[8] = mark
            buttons[7].config(text=mark)
            count += 1

    elif i == 9:
        if i in chiffres:
            chiffres.remove(i)
            if count % 2 == 0:
                mark = "X"
            else:
                mark = "O"
            panels[9] = mark
            buttons[8].config(text=mark)
            count += 1



  # Vérifier s'il y a un gagnant
    gagnant = Win()
    if gagnant != "":
        if gagnant == "X":
            messagebox.showinfo("Fin du jeu", "Joueur 1 gagne !")
        else:
            messagebox.showinfo("Fin du jeu", "Joueur 2 gagne !")
        fenetre.destroy()
        return

    # Vérifier le match nul
    if count == 9:
        messagebox.showinfo("Fin du jeu", "Match nul !")
        fenetre.destroy()
