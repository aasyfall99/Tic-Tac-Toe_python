# %% [markdown]
# <a href="https://colab.research.google.com/github/aasyfall99/Tic-Tac-Toe_python/blob/main/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tkinter as tk
from tkinter import messagebox

#creation de la fentre
fenetre = tk.Tk()
fenetre.title("TIC-TAC-TOE")


#definition de la liste des positions
chiffres = ([1, 2, 3, 4, 5, 6, 7, 8, 9])

#la variable mark

mark = ""

#attribution d'une valeur à la variable count

count = 0

#creation d'une liste panel

panels = (["", chiffres[0], chiffres[1], chiffres[2], chiffres[3], chiffres[4], chiffres[5], chiffres[6], chiffres[7], chiffres[8]])
